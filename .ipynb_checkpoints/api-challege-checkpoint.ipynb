# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countrys = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    c = citipy.nearest_city(lat_lng[0], lat_lng[1])
    country = c.country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countrys.append(country)
# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 615

# %%
len(countrys)
# Out:
# 615

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

query_url = f"{url}appid={api_key}&units={units}&q="

# %%
response = requests.get(query_url+ "sunnyside").json()

# %%
print(response)
# Out:
# {'coord': {'lon': -53.92, 'lat': 47.86}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 6.39, 'pressure': 1024, 'humidity': 36, 'temp_min': 6.11, 'temp_max': 6.67}, 'wind': {'speed': 2.853, 'deg': 261}, 'clouds': {'all': 2}, 'dt': 1570413080, 'sys': {'type': 3, 'id': 2002737, 'country': 'CA', 'sunrise': 1570354874, 'sunset': 1570395975}, 'timezone': -9000, 'id': 6159599, 'name': 'Sunnyside', 'cod': 200}

# %%
import pyowm

# %%
owm = pyowm.OWM('0ee6cdb04feec028b3a20a5482451035')

#observation = owm.weather_at_place("Phoenix")
#weather = observation.get_weather()
#print(weather)

# %%
new_city = []
new_country = []
temp = []
humidity = []
windspeed = []
longitude = []
latitude = []
datetime = []
clouds = []

def create_Data(x):
    observation = owm.weather_at_place(cities[x])
    weather = observation.get_weather()
    loc = observation.get_location()
    w = weather.get_wind()["speed"]
    t = weather.get_temperature("fahrenheit")["temp_max"]
    h = weather.get_humidity()
    lo = loc.get_lon()
    la = loc.get_lat()
    d = weather.get_reference_time(timeformat='date')
    c = weather.get_clouds()
    datetime.append(d)
    new_city.append(cities[x])
    new_country.append(countrys[x])
    windspeed.append(w)
    humidity.append(h)
    temp.append(t)
    longitude.append(lo)
    latitude.append(la)
    clouds.append(c)
    
    return()

# %%
import pyowm
count = 0
set_count = 1
for x in range(len(cities)):   
    try:
        create_Data(x)

        if (count < 49):

                #count = 0
                #new_city.append(city)


                
                print(f" Processing Record {count} of the Set {set_count} : {cities[x]}")
                count += 1
        else:
                count = 0
                set_count +=1
                count += 1
                #new_city.append(city)
    except:
        print(f"City not found. Skipping...{count}")
print("-----------Data Collection Complete------------")
# Out:
#  Processing Record 0 of the Set 1 : albany
#  Processing Record 1 of the Set 1 : ushuaia
#  Processing Record 2 of the Set 1 : busselton
#  Processing Record 3 of the Set 1 : karasuyama
# City not found. Skipping...4
#  Processing Record 4 of the Set 1 : rikitea
#  Processing Record 5 of the Set 1 : najran
#  Processing Record 6 of the Set 1 : barcelos
#  Processing Record 7 of the Set 1 : sambava
#  Processing Record 8 of the Set 1 : saint-philippe
#  Processing Record 9 of the Set 1 : rawson
#  Processing Record 10 of the Set 1 : maniitsoq
#  Processing Record 11 of the Set 1 : qaanaaq
#  Processing Record 12 of the Set 1 : barrow
#  Processing Record 13 of the Set 1 : puerto ayora
#  Processing Record 14 of the Set 1 : mahebourg
# City not found. Skipping...15
#  Processing Record 15 of the Set 1 : yulara
#  Processing Record 16 of the Set 1 : mangrol
#  Processing Record 17 of the Set 1 : saint george
#  Processing Record 18 of the Set 1 : paamiut
#  Processing Record 19 of the Set 1 : turayf
#  Processing Record 20 of the Set 1 : lovozero
#  Processing Record 21 of the Set 1 : mar del plata
#  Processing Record 22 of the Set 1 : bluff
# City not found. Skipping...23
#  Processing Record 23 of the Set 1 : punta arenas
#  Processing Record 24 of the Set 1 : zhigansk
#  Processing Record 25 of the Set 1 : yellowknife
#  Processing Record 26 of the Set 1 : saldanha
#  Processing Record 27 of the Set 1 : shimoda
# City not found. Skipping...28
# City not found. Skipping...28
#  Processing Record 28 of the Set 1 : vaini
#  Processing Record 29 of the Set 1 : saskylakh
#  Processing Record 30 of the Set 1 : sao filipe
#  Processing Record 31 of the Set 1 : llanes
#  Processing Record 32 of the Set 1 : bulgan
#  Processing Record 33 of the Set 1 : tagusao
#  Processing Record 34 of the Set 1 : dongsheng
#  Processing Record 35 of the Set 1 : havelock
#  Processing Record 36 of the Set 1 : macau
#  Processing Record 37 of the Set 1 : mataura
#  Processing Record 38 of the Set 1 : pionerskiy
# City not found. Skipping...39
#  Processing Record 39 of the Set 1 : hithadhoo
# City not found. Skipping...40
#  Processing Record 40 of the Set 1 : korem
#  Processing Record 41 of the Set 1 : flinders
#  Processing Record 42 of the Set 1 : carnarvon
#  Processing Record 43 of the Set 1 : sedalia
#  Processing Record 44 of the Set 1 : tokur
#  Processing Record 45 of the Set 1 : kaitangata
# City not found. Skipping...46
#  Processing Record 46 of the Set 1 : kijang
#  Processing Record 47 of the Set 1 : belaya gora
#  Processing Record 48 of the Set 1 : rovaniemi
#  Processing Record 1 of the Set 2 : leningradskiy
#  Processing Record 2 of the Set 2 : georgetown
#  Processing Record 3 of the Set 2 : danao
#  Processing Record 4 of the Set 2 : amahai
#  Processing Record 5 of the Set 2 : ancud
#  Processing Record 6 of the Set 2 : uruzgan
#  Processing Record 7 of the Set 2 : acapulco
#  Processing Record 8 of the Set 2 : larsnes
#  Processing Record 9 of the Set 2 : avarua
#  Processing Record 10 of the Set 2 : shellbrook
#  Processing Record 11 of the Set 2 : avera
#  Processing Record 12 of the Set 2 : opuwo
#  Processing Record 13 of the Set 2 : eureka
#  Processing Record 14 of the Set 2 : walvis bay
#  Processing Record 15 of the Set 2 : plainview
# City not found. Skipping...16
#  Processing Record 16 of the Set 2 : iqaluit
#  Processing Record 17 of the Set 2 : asosa
#  Processing Record 18 of the Set 2 : lebu
#  Processing Record 19 of the Set 2 : bredasdorp
#  Processing Record 20 of the Set 2 : victoria
#  Processing Record 21 of the Set 2 : kapaa
#  Processing Record 22 of the Set 2 : hobart
#  Processing Record 23 of the Set 2 : port alfred
#  Processing Record 24 of the Set 2 : cape town
#  Processing Record 25 of the Set 2 : geraldton
#  Processing Record 26 of the Set 2 : port elizabeth
#  Processing Record 27 of the Set 2 : krasnyy kholm
# City not found. Skipping...28
#  Processing Record 28 of the Set 2 : peto
#  Processing Record 29 of the Set 2 : tazovskiy
#  Processing Record 30 of the Set 2 : husavik
#  Processing Record 31 of the Set 2 : kahului
#  Processing Record 32 of the Set 2 : kawalu
# City not found. Skipping...33
#  Processing Record 33 of the Set 2 : kabo
# City not found. Skipping...34
# City not found. Skipping...34
#  Processing Record 34 of the Set 2 : grindavik
#  Processing Record 35 of the Set 2 : novikovo
# City not found. Skipping...36
#  Processing Record 36 of the Set 2 : port-gentil
#  Processing Record 37 of the Set 2 : sinnamary
#  Processing Record 38 of the Set 2 : alofi
#  Processing Record 39 of the Set 2 : kholtoson
#  Processing Record 40 of the Set 2 : mulege
#  Processing Record 41 of the Set 2 : longonjo
#  Processing Record 42 of the Set 2 : nikolskoye
#  Processing Record 43 of the Set 2 : hualmay
#  Processing Record 44 of the Set 2 : puro
#  Processing Record 45 of the Set 2 : bethel
#  Processing Record 46 of the Set 2 : ahuimanu
#  Processing Record 47 of the Set 2 : hermanus
#  Processing Record 48 of the Set 2 : berlevag
# City not found. Skipping...1
#  Processing Record 1 of the Set 3 : upernavik
#  Processing Record 2 of the Set 3 : dikson
#  Processing Record 3 of the Set 3 : kamalasai
#  Processing Record 4 of the Set 3 : mehran
#  Processing Record 5 of the Set 3 : udachnyy
#  Processing Record 6 of the Set 3 : port hawkesbury
#  Processing Record 7 of the Set 3 : potiskum
#  Processing Record 8 of the Set 3 : hilo
#  Processing Record 9 of the Set 3 : tiznit
#  Processing Record 10 of the Set 3 : lompoc
#  Processing Record 11 of the Set 3 : hasaki
#  Processing Record 12 of the Set 3 : poronaysk
#  Processing Record 13 of the Set 3 : kenai
#  Processing Record 14 of the Set 3 : kaeo
#  Processing Record 15 of the Set 3 : jalu
#  Processing Record 16 of the Set 3 : narsaq
#  Processing Record 17 of the Set 3 : tecoanapa
#  Processing Record 18 of the Set 3 : windhoek
#  Processing Record 19 of the Set 3 : gaya
#  Processing Record 20 of the Set 3 : airai
#  Processing Record 21 of the Set 3 : bull savanna
#  Processing Record 22 of the Set 3 : sao bento do sul
#  Processing Record 23 of the Set 3 : cherskiy
#  Processing Record 24 of the Set 3 : sibolga
# City not found. Skipping...25
#  Processing Record 25 of the Set 3 : jamestown
#  Processing Record 26 of the Set 3 : saint-joseph
# City not found. Skipping...27
#  Processing Record 27 of the Set 3 : nanortalik
#  Processing Record 28 of the Set 3 : ponta do sol
#  Processing Record 29 of the Set 3 : ambilobe
#  Processing Record 30 of the Set 3 : athens
#  Processing Record 31 of the Set 3 : iskateley
#  Processing Record 32 of the Set 3 : chaman
#  Processing Record 33 of the Set 3 : lircay
#  Processing Record 34 of the Set 3 : la sarre
#  Processing Record 35 of the Set 3 : graulhet
#  Processing Record 36 of the Set 3 : fort saint james
#  Processing Record 37 of the Set 3 : wilkie
#  Processing Record 38 of the Set 3 : yertsevo
#  Processing Record 39 of the Set 3 : thompson
#  Processing Record 40 of the Set 3 : katsuura
# City not found. Skipping...41
#  Processing Record 41 of the Set 3 : pak phanang
#  Processing Record 42 of the Set 3 : la paz
#  Processing Record 43 of the Set 3 : maraa
#  Processing Record 44 of the Set 3 : half moon bay
#  Processing Record 45 of the Set 3 : salalah
# City not found. Skipping...46
#  Processing Record 46 of the Set 3 : kodiak
#  Processing Record 47 of the Set 3 : independence
#  Processing Record 48 of the Set 3 : ucluelet
#  Processing Record 1 of the Set 4 : tuatapere
#  Processing Record 2 of the Set 4 : neuquen
#  Processing Record 3 of the Set 4 : severo-kurilsk
#  Processing Record 4 of the Set 4 : chalus
#  Processing Record 5 of the Set 4 : sol-iletsk
#  Processing Record 6 of the Set 4 : skibbereen
#  Processing Record 7 of the Set 4 : bara
#  Processing Record 8 of the Set 4 : bukachacha
# City not found. Skipping...9
#  Processing Record 9 of the Set 4 : hearst
#  Processing Record 10 of the Set 4 : mayumba
#  Processing Record 11 of the Set 4 : bagdarin
#  Processing Record 12 of the Set 4 : saint-pierre
#  Processing Record 13 of the Set 4 : butaritari
#  Processing Record 14 of the Set 4 : atasu
#  Processing Record 15 of the Set 4 : khatanga
#  Processing Record 16 of the Set 4 : camacha
#  Processing Record 17 of the Set 4 : provideniya
#  Processing Record 18 of the Set 4 : resistencia
#  Processing Record 19 of the Set 4 : ilulissat
#  Processing Record 20 of the Set 4 : ribeira grande
# City not found. Skipping...21
#  Processing Record 21 of the Set 4 : masyaf
#  Processing Record 22 of the Set 4 : krasnik
#  Processing Record 23 of the Set 4 : oranjemund
#  Processing Record 24 of the Set 4 : caravelas
#  Processing Record 25 of the Set 4 : atuona
#  Processing Record 26 of the Set 4 : lavrentiya
# City not found. Skipping...27
#  Processing Record 27 of the Set 4 : devils lake
#  Processing Record 28 of the Set 4 : zhangye
#  Processing Record 29 of the Set 4 : rexburg
# City not found. Skipping...30
#  Processing Record 30 of the Set 4 : vardo
#  Processing Record 31 of the Set 4 : dingle
#  Processing Record 32 of the Set 4 : taoudenni
#  Processing Record 33 of the Set 4 : wanaka
#  Processing Record 34 of the Set 4 : east london
#  Processing Record 35 of the Set 4 : port hedland
#  Processing Record 36 of the Set 4 : yar-sale
#  Processing Record 37 of the Set 4 : kattivakkam
#  Processing Record 38 of the Set 4 : abha
#  Processing Record 39 of the Set 4 : itarema
#  Processing Record 40 of the Set 4 : esmeraldas
# City not found. Skipping...41
#  Processing Record 41 of the Set 4 : dickinson
#  Processing Record 42 of the Set 4 : bimbo
#  Processing Record 43 of the Set 4 : vila franca do campo
#  Processing Record 44 of the Set 4 : pevek
#  Processing Record 45 of the Set 4 : belmonte
# City not found. Skipping...46
#  Processing Record 46 of the Set 4 : vuktyl
#  Processing Record 47 of the Set 4 : nagorsk
#  Processing Record 48 of the Set 4 : dharchula
#  Processing Record 1 of the Set 5 : san matias
#  Processing Record 2 of the Set 5 : san patricio
#  Processing Record 3 of the Set 5 : jumla
#  Processing Record 4 of the Set 5 : primo tapia
#  Processing Record 5 of the Set 5 : lerwick
#  Processing Record 6 of the Set 5 : correntina
#  Processing Record 7 of the Set 5 : sitka
#  Processing Record 8 of the Set 5 : yurimaguas
#  Processing Record 9 of the Set 5 : masallatah
#  Processing Record 10 of the Set 5 : codrington
#  Processing Record 11 of the Set 5 : torbay
# City not found. Skipping...12
#  Processing Record 12 of the Set 5 : tateyama
#  Processing Record 13 of the Set 5 : qandala
#  Processing Record 14 of the Set 5 : pisco
#  Processing Record 15 of the Set 5 : ostrovnoy
# City not found. Skipping...16
#  Processing Record 16 of the Set 5 : luderitz
#  Processing Record 17 of the Set 5 : adre
#  Processing Record 18 of the Set 5 : warrington
# City not found. Skipping...19
#  Processing Record 19 of the Set 5 : veraval
#  Processing Record 20 of the Set 5 : daru
#  Processing Record 21 of the Set 5 : beyneu
#  Processing Record 22 of the Set 5 : tuktoyaktuk
#  Processing Record 23 of the Set 5 : chokurdakh
#  Processing Record 24 of the Set 5 : bashtanka
#  Processing Record 25 of the Set 5 : valparaiso
#  Processing Record 26 of the Set 5 : norman wells
#  Processing Record 27 of the Set 5 : hofn
#  Processing Record 28 of the Set 5 : puerto del rosario
#  Processing Record 29 of the Set 5 : biak
# City not found. Skipping...30
#  Processing Record 30 of the Set 5 : lagoa
#  Processing Record 31 of the Set 5 : castanos
#  Processing Record 32 of the Set 5 : timra
#  Processing Record 33 of the Set 5 : roebourne
#  Processing Record 34 of the Set 5 : bambous virieux
#  Processing Record 35 of the Set 5 : podgornoye
#  Processing Record 36 of the Set 5 : red bank
#  Processing Record 37 of the Set 5 : russell
#  Processing Record 38 of the Set 5 : cabinda
#  Processing Record 39 of the Set 5 : sherlovaya gora
#  Processing Record 40 of the Set 5 : tiksi
# City not found. Skipping...41
#  Processing Record 41 of the Set 5 : waddan
#  Processing Record 42 of the Set 5 : aripuana
#  Processing Record 43 of the Set 5 : hattiesburg
#  Processing Record 44 of the Set 5 : saint-denis
# City not found. Skipping...45
#  Processing Record 45 of the Set 5 : santa cruz del norte
#  Processing Record 46 of the Set 5 : komsomolskiy
# City not found. Skipping...47
#  Processing Record 47 of the Set 5 : gotsu
#  Processing Record 48 of the Set 5 : carballo
#  Processing Record 1 of the Set 6 : tasiilaq
#  Processing Record 2 of the Set 6 : abapo
# City not found. Skipping...3
# City not found. Skipping...3
#  Processing Record 3 of the Set 6 : reconquista
#  Processing Record 4 of the Set 6 : hare bay
#  Processing Record 5 of the Set 6 : nyurba
#  Processing Record 6 of the Set 6 : naze
#  Processing Record 7 of the Set 6 : pavlovsk
#  Processing Record 8 of the Set 6 : egvekinot
#  Processing Record 9 of the Set 6 : pacific grove
#  Processing Record 10 of the Set 6 : juneau
#  Processing Record 11 of the Set 6 : talnakh
#  Processing Record 12 of the Set 6 : kirakira
#  Processing Record 13 of the Set 6 : rurrenabaque
#  Processing Record 14 of the Set 6 : shache
#  Processing Record 15 of the Set 6 : verkhnetulomskiy
#  Processing Record 16 of the Set 6 : faanui
#  Processing Record 17 of the Set 6 : constitucion
#  Processing Record 18 of the Set 6 : penzance
#  Processing Record 19 of the Set 6 : kutum
#  Processing Record 20 of the Set 6 : ahipara
#  Processing Record 21 of the Set 6 : kozmodemyansk
#  Processing Record 22 of the Set 6 : cururupu
#  Processing Record 23 of the Set 6 : tombouctou
#  Processing Record 24 of the Set 6 : castro
#  Processing Record 25 of the Set 6 : baley
#  Processing Record 26 of the Set 6 : atar
#  Processing Record 27 of the Set 6 : vila do maio
# City not found. Skipping...28
#  Processing Record 28 of the Set 6 : semey
#  Processing Record 29 of the Set 6 : quatre cocos
#  Processing Record 30 of the Set 6 : nanakuli
#  Processing Record 31 of the Set 6 : araouane
#  Processing Record 32 of the Set 6 : portel
#  Processing Record 33 of the Set 6 : kandi
#  Processing Record 34 of the Set 6 : gonbad-e qabus
# City not found. Skipping...35
#  Processing Record 35 of the Set 6 : vila velha
#  Processing Record 36 of the Set 6 : nelson bay
#  Processing Record 37 of the Set 6 : wucheng
#  Processing Record 38 of the Set 6 : xinyu
#  Processing Record 39 of the Set 6 : takoradi
#  Processing Record 40 of the Set 6 : irtyshskiy
#  Processing Record 41 of the Set 6 : nome
#  Processing Record 42 of the Set 6 : ketchikan
#  Processing Record 43 of the Set 6 : novyy urengoy
#  Processing Record 44 of the Set 6 : cavalcante
# City not found. Skipping...45
#  Processing Record 45 of the Set 6 : chuy
#  Processing Record 46 of the Set 6 : padang
#  Processing Record 47 of the Set 6 : aklavik
#  Processing Record 48 of the Set 6 : coahuayana
#  Processing Record 1 of the Set 7 : jiwani
#  Processing Record 2 of the Set 7 : doha
# City not found. Skipping...3
#  Processing Record 3 of the Set 7 : zaysan
# City not found. Skipping...4
#  Processing Record 4 of the Set 7 : madison
#  Processing Record 5 of the Set 7 : praia da vitoria
#  Processing Record 6 of the Set 7 : guiratinga
# City not found. Skipping...7
#  Processing Record 7 of the Set 7 : san carlos de bariloche
# City not found. Skipping...8
#  Processing Record 8 of the Set 7 : ust-omchug
#  Processing Record 9 of the Set 7 : poum
#  Processing Record 10 of the Set 7 : vallenar
#  Processing Record 11 of the Set 7 : yatou
#  Processing Record 12 of the Set 7 : brewster
#  Processing Record 13 of the Set 7 : bay roberts
#  Processing Record 14 of the Set 7 : la asuncion
#  Processing Record 15 of the Set 7 : college
#  Processing Record 16 of the Set 7 : edd
#  Processing Record 17 of the Set 7 : avesta
#  Processing Record 18 of the Set 7 : kruisfontein
#  Processing Record 19 of the Set 7 : wysokie mazowieckie
#  Processing Record 20 of the Set 7 : vsetaty
#  Processing Record 21 of the Set 7 : hobyo
#  Processing Record 22 of the Set 7 : koping
#  Processing Record 23 of the Set 7 : juruti
#  Processing Record 24 of the Set 7 : alekseyevsk
#  Processing Record 25 of the Set 7 : birao
# City not found. Skipping...26
#  Processing Record 26 of the Set 7 : bilibino
# City not found. Skipping...27
#  Processing Record 27 of the Set 7 : arraial do cabo
# City not found. Skipping...28
#  Processing Record 28 of the Set 7 : road town
#  Processing Record 29 of the Set 7 : sokoni
#  Processing Record 30 of the Set 7 : coihaique
# City not found. Skipping...31
# City not found. Skipping...31
#  Processing Record 31 of the Set 7 : lorengau
#  Processing Record 32 of the Set 7 : viesca
#  Processing Record 33 of the Set 7 : muriti
#  Processing Record 34 of the Set 7 : bathsheba
#  Processing Record 35 of the Set 7 : piedecuesta
#  Processing Record 36 of the Set 7 : wattegama
#  Processing Record 37 of the Set 7 : sao joao da barra
# City not found. Skipping...38
# City not found. Skipping...38
#  Processing Record 38 of the Set 7 : boyabat
#  Processing Record 39 of the Set 7 : sisophon
# City not found. Skipping...40
#  Processing Record 40 of the Set 7 : icod de los vinos
# City not found. Skipping...41
#  Processing Record 41 of the Set 7 : makakilo city
#  Processing Record 42 of the Set 7 : mincivan
# City not found. Skipping...43
#  Processing Record 43 of the Set 7 : souillac
#  Processing Record 44 of the Set 7 : namibe
#  Processing Record 45 of the Set 7 : melfi
#  Processing Record 46 of the Set 7 : camopi
#  Processing Record 47 of the Set 7 : artesia
#  Processing Record 48 of the Set 7 : matsuura
#  Processing Record 1 of the Set 8 : monrovia
#  Processing Record 2 of the Set 8 : meulaboh
#  Processing Record 3 of the Set 8 : lodwar
#  Processing Record 4 of the Set 8 : pshekhskaya
# City not found. Skipping...5
#  Processing Record 5 of the Set 8 : chuzhou
#  Processing Record 6 of the Set 8 : kamarion
# City not found. Skipping...7
#  Processing Record 7 of the Set 8 : stryn
#  Processing Record 8 of the Set 8 : dauriya
#  Processing Record 9 of the Set 8 : slave lake
# City not found. Skipping...10
#  Processing Record 10 of the Set 8 : bad durrenberg
#  Processing Record 11 of the Set 8 : adrar
#  Processing Record 12 of the Set 8 : lasa
#  Processing Record 13 of the Set 8 : mansar
#  Processing Record 14 of the Set 8 : bayanday
#  Processing Record 15 of the Set 8 : hanzhong
# City not found. Skipping...16
#  Processing Record 16 of the Set 8 : lamu
#  Processing Record 17 of the Set 8 : muyezerskiy
#  Processing Record 18 of the Set 8 : buala
#  Processing Record 19 of the Set 8 : conceicao da barra
#  Processing Record 20 of the Set 8 : mount isa
#  Processing Record 21 of the Set 8 : jasper
# City not found. Skipping...22
#  Processing Record 22 of the Set 8 : norfolk
#  Processing Record 23 of the Set 8 : nizwa
#  Processing Record 24 of the Set 8 : miragoane
# City not found. Skipping...25
#  Processing Record 25 of the Set 8 : fortuna
#  Processing Record 26 of the Set 8 : nabire
#  Processing Record 27 of the Set 8 : auki
#  Processing Record 28 of the Set 8 : gejiu
#  Processing Record 29 of the Set 8 : jinchang
#  Processing Record 30 of the Set 8 : rodez
#  Processing Record 31 of the Set 8 : deputatskiy
#  Processing Record 32 of the Set 8 : luleburgaz
#  Processing Record 33 of the Set 8 : ukiah
#  Processing Record 34 of the Set 8 : makurdi
#  Processing Record 35 of the Set 8 : bangassou
#  Processing Record 36 of the Set 8 : guerrero negro
#  Processing Record 37 of the Set 8 : catuday
#  Processing Record 38 of the Set 8 : ous
#  Processing Record 39 of the Set 8 : pangnirtung
#  Processing Record 40 of the Set 8 : sobolevo
#  Processing Record 41 of the Set 8 : sabang
#  Processing Record 42 of the Set 8 : matara
#  Processing Record 43 of the Set 8 : hay river
#  Processing Record 44 of the Set 8 : san juan
#  Processing Record 45 of the Set 8 : richards bay
#  Processing Record 46 of the Set 8 : galle
#  Processing Record 47 of the Set 8 : grenfell
#  Processing Record 48 of the Set 8 : del rio
#  Processing Record 1 of the Set 9 : alice springs
#  Processing Record 2 of the Set 9 : bushehr
# City not found. Skipping...3
#  Processing Record 3 of the Set 9 : dunedin
#  Processing Record 4 of the Set 9 : tselinnoye
#  Processing Record 5 of the Set 9 : verkhnedneprovskiy
# City not found. Skipping...6
#  Processing Record 6 of the Set 9 : umm lajj
#  Processing Record 7 of the Set 9 : zhuanghe
#  Processing Record 8 of the Set 9 : longyearbyen
#  Processing Record 9 of the Set 9 : severomorsk
#  Processing Record 10 of the Set 9 : seymchan
#  Processing Record 11 of the Set 9 : hambantota
#  Processing Record 12 of the Set 9 : secaucus
#  Processing Record 13 of the Set 9 : henties bay
#  Processing Record 14 of the Set 9 : sanandaj
#  Processing Record 15 of the Set 9 : beoumi
#  Processing Record 16 of the Set 9 : harvard
#  Processing Record 17 of the Set 9 : sonepur
#  Processing Record 18 of the Set 9 : katangli
#  Processing Record 19 of the Set 9 : ozernovskiy
#  Processing Record 20 of the Set 9 : baruun-urt
#  Processing Record 21 of the Set 9 : gladstone
#  Processing Record 22 of the Set 9 : makokou
#  Processing Record 23 of the Set 9 : yarmouth
#  Processing Record 24 of the Set 9 : noumea
# City not found. Skipping...25
#  Processing Record 25 of the Set 9 : muros
# City not found. Skipping...26
#  Processing Record 26 of the Set 9 : raudeberg
#  Processing Record 27 of the Set 9 : karratha
#  Processing Record 28 of the Set 9 : bonavista
#  Processing Record 29 of the Set 9 : warrensburg
#  Processing Record 30 of the Set 9 : broome
#  Processing Record 31 of the Set 9 : kabelvag
#  Processing Record 32 of the Set 9 : madimba
#  Processing Record 33 of the Set 9 : khani
#  Processing Record 34 of the Set 9 : klaksvik
#  Processing Record 35 of the Set 9 : cidreira
#  Processing Record 36 of the Set 9 : tevriz
#  Processing Record 37 of the Set 9 : kavaratti
#  Processing Record 38 of the Set 9 : mozarlandia
#  Processing Record 39 of the Set 9 : bilma
#  Processing Record 40 of the Set 9 : kampot
#  Processing Record 41 of the Set 9 : san cristobal
#  Processing Record 42 of the Set 9 : buta
#  Processing Record 43 of the Set 9 : methoni
#  Processing Record 44 of the Set 9 : fresnillo
# City not found. Skipping...45
#  Processing Record 45 of the Set 9 : synya
#  Processing Record 46 of the Set 9 : sola
#  Processing Record 47 of the Set 9 : shingu
#  Processing Record 48 of the Set 9 : khilok
#  Processing Record 1 of the Set 10 : aksarka
#  Processing Record 2 of the Set 10 : bereda
#  Processing Record 3 of the Set 10 : fortuna foothills
#  Processing Record 4 of the Set 10 : shelburne
#  Processing Record 5 of the Set 10 : cabedelo
# City not found. Skipping...6
#  Processing Record 6 of the Set 10 : tecpan
#  Processing Record 7 of the Set 10 : hyeres
#  Processing Record 8 of the Set 10 : toropets
#  Processing Record 9 of the Set 10 : esperance
#  Processing Record 10 of the Set 10 : slyudyanka
#  Processing Record 11 of the Set 10 : paracatu
#  Processing Record 12 of the Set 10 : zyryanka
#  Processing Record 13 of the Set 10 : solwezi
#  Processing Record 14 of the Set 10 : nalut
#  Processing Record 15 of the Set 10 : puerto ayacucho
# City not found. Skipping...16
#  Processing Record 16 of the Set 10 : margate
#  Processing Record 17 of the Set 10 : inirida
#  Processing Record 18 of the Set 10 : riyadh
#  Processing Record 19 of the Set 10 : batagay-alyta
#  Processing Record 20 of the Set 10 : kamenka
#  Processing Record 21 of the Set 10 : lata
#  Processing Record 22 of the Set 10 : bubaque
#  Processing Record 23 of the Set 10 : shakawe
#  Processing Record 24 of the Set 10 : pahrump
# City not found. Skipping...25
#  Processing Record 25 of the Set 10 : santa isabel do rio negro
#  Processing Record 26 of the Set 10 : redding
# City not found. Skipping...27
#  Processing Record 27 of the Set 10 : peque
#  Processing Record 28 of the Set 10 : luancheng
#  Processing Record 29 of the Set 10 : kindu
#  Processing Record 30 of the Set 10 : uuemoisa
#  Processing Record 31 of the Set 10 : halden
#  Processing Record 32 of the Set 10 : gidole
#  Processing Record 33 of the Set 10 : port moresby
# City not found. Skipping...34
#  Processing Record 34 of the Set 10 : durango
#  Processing Record 35 of the Set 10 : paramonga
#  Processing Record 36 of the Set 10 : winslow
#  Processing Record 37 of the Set 10 : usoke
#  Processing Record 38 of the Set 10 : narasaraopet
#  Processing Record 39 of the Set 10 : davidson
#  Processing Record 40 of the Set 10 : atagay
#  Processing Record 41 of the Set 10 : morehead
#  Processing Record 42 of the Set 10 : baculin
#  Processing Record 43 of the Set 10 : haapsalu
#  Processing Record 44 of the Set 10 : nuristan
#  Processing Record 45 of the Set 10 : tilichiki
#  Processing Record 46 of the Set 10 : pecanha
# City not found. Skipping...47
#  Processing Record 47 of the Set 10 : port lincoln
#  Processing Record 48 of the Set 10 : san rafael del sur
#  Processing Record 1 of the Set 11 : fairbanks
#  Processing Record 2 of the Set 11 : svobodnyy
#  Processing Record 3 of the Set 11 : isangel
#  Processing Record 4 of the Set 11 : basco
#  Processing Record 5 of the Set 11 : seabra
#  Processing Record 6 of the Set 11 : jacareacanga
#  Processing Record 7 of the Set 11 : tigil
#  Processing Record 8 of the Set 11 : mizan teferi
#  Processing Record 9 of the Set 11 : beloha
#  Processing Record 10 of the Set 11 : papetoai
#  Processing Record 11 of the Set 11 : te anau
#  Processing Record 12 of the Set 11 : north bend
#  Processing Record 13 of the Set 11 : podor
#  Processing Record 14 of the Set 11 : vanimo
#  Processing Record 15 of the Set 11 : ginir
#  Processing Record 16 of the Set 11 : mauguio
#  Processing Record 17 of the Set 11 : hamilton
#  Processing Record 18 of the Set 11 : saint-francois
#  Processing Record 19 of the Set 11 : jiexiu
#  Processing Record 20 of the Set 11 : xam nua
#  Processing Record 21 of the Set 11 : griffith
#  Processing Record 22 of the Set 11 : santa maria
#  Processing Record 23 of the Set 11 : kodinsk
#  Processing Record 24 of the Set 11 : shubarshi
#  Processing Record 25 of the Set 11 : novo aripuana
#  Processing Record 26 of the Set 11 : kumluca
#  Processing Record 27 of the Set 11 : devonport
#  Processing Record 28 of the Set 11 : uvat
#  Processing Record 29 of the Set 11 : garowe
#  Processing Record 30 of the Set 11 : gazli
#  Processing Record 31 of the Set 11 : pacajus
#  Processing Record 32 of the Set 11 : khorixas
#  Processing Record 33 of the Set 11 : taltal
#  Processing Record 34 of the Set 11 : coquimbo
#  Processing Record 35 of the Set 11 : meadow lake
# City not found. Skipping...36
# City not found. Skipping...36
#  Processing Record 36 of the Set 11 : wajid
#  Processing Record 37 of the Set 11 : batemans bay
#  Processing Record 38 of the Set 11 : necochea
#  Processing Record 39 of the Set 11 : moose factory
#  Processing Record 40 of the Set 11 : shahrud
#  Processing Record 41 of the Set 11 : san andres
#  Processing Record 42 of the Set 11 : mweka
#  Processing Record 43 of the Set 11 : ambunti
#  Processing Record 44 of the Set 11 : rio grande
#  Processing Record 45 of the Set 11 : centralia
# City not found. Skipping...46
#  Processing Record 46 of the Set 11 : safford
#  Processing Record 47 of the Set 11 : tartagal
#  Processing Record 48 of the Set 11 : sibut
#  Processing Record 1 of the Set 12 : oktyabrskiy
#  Processing Record 2 of the Set 12 : kholuy
#  Processing Record 3 of the Set 12 : altay
#  Processing Record 4 of the Set 12 : soe
# -----------Data Collection Complete------------

# %%
API_DF = pd.DataFrame({"City": new_city,
                      "Country ID" : new_country,
                      "Date": datetime,
                      "Cloudiness": clouds,
                      "Humidity": humidity,
                      "Lat": longitude,
                      "Lon": latitude,
                      "Max_temp": temp,
                      "Wind Speed": windspeed})

# %%
API_DF
# Out:
#             City Country ID                       Date  Cloudiness  Humidity  \
# 0         albany         au  2019-10-07 01:52:04+00:00          90        77
# 1        ushuaia         ar  2019-10-07 01:57:48+00:00          65        90
# 2      busselton         au  2019-10-07 01:51:57+00:00           3        59
# 3     karasuyama         jp  2019-10-07 01:57:49+00:00          75        72
# 4        rikitea         pf  2019-10-07 01:57:50+00:00         100        86
# ..           ...        ...                        ...         ...       ...
# 539       mortka         ru  2019-10-07 02:01:38+00:00          97        95
# 540  oktyabrskiy         ru  2019-10-07 02:01:38+00:00          90        91
# 541       kholuy         ru  2019-10-07 02:01:39+00:00         100       100
# 542        altay         cn  2019-10-07 02:01:39+00:00           0        23
# 543          soe         id  2019-10-07 02:01:39+00:00          20        96
#
#         Lat    Lon  Max_temp  Wind Speed
# 0    -73.75  42.65     66.20       6.700
# 1    -68.31 -54.81     28.00       3.030
# 2    115.35 -33.64     66.99       1.340
# 3    140.15  36.65     80.01       2.600
# 4   -134.97 -23.12     73.74       5.060
# ..      ...    ...       ...         ...
# 539   66.02  59.33     45.32       1.954
# 540   37.97  55.61     35.60       7.000
# 541   41.87  56.58     34.34       3.030
# 542   88.13  47.83     53.96       1.270
# 543   26.05  57.91     33.80       2.100
#
# [544 rows x 9 columns]

# %%
API_DF["Country ID"].value_counts()
# Out:
# ru    79
# us    48
# br    30
# ca    29
# au    22
#       ..
# sj     1
# jm     1
# ck     1
# bb     1
# ge     1
# Name: Country ID, Length: 112, dtype: int64

# %%
API_DF.info()
API_DF.to_csv("output.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 544 entries, 0 to 543
# Data columns (total 9 columns):
# City          544 non-null object
# Country ID    544 non-null object
# Date          544 non-null object
# Cloudiness    544 non-null int64
# Humidity      544 non-null int64
# Lat           544 non-null float64
# Lon           544 non-null float64
# Max_temp      544 non-null float64
# Wind Speed    544 non-null float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 38.4+ KB

# %%
def longitude_vs_max_temp():
    plt.scatter(API_DF["Lon"], API_DF["Max_temp"], marker=".")
    plt.xlabel("Longitude")
    plt.ylabel("Max Temperature")
    plt.title("City Longitude Vs Max Temperature")
    plt.grid()
longitude_vs_max_temp()

# %%
def longitude_vs_Humidity():
    plt.scatter(API_DF["Lon"], API_DF["Humidity"], marker=".")
    plt.xlabel("Longitude")
    plt.ylabel("Humidity")
    plt.title("City Longitude Vs Humidity")
    plt.grid()
    plt.ylim(0,100)
longitude_vs_Humidity()

# %%
def longitude_vs_Cloudiness():
    plt.scatter(API_DF["Lon"], API_DF["Cloudiness"], marker=".")
    plt.xlabel("Longitude")
    plt.ylabel("Cloudiness")
    plt.title("City Longitude Vs Cloudiness")
    plt.grid()
    plt.ylim(0,100)
longitude_vs_Cloudiness()

# %%
def longitude_vs_Wind_Speed():
    plt.scatter(API_DF["Lon"], API_DF["Wind Speed"], marker=".")
    plt.xlabel("Longitude")
    plt.ylabel("Wind Speed")
    plt.title("City Longitude Vs Wind Speed")
    plt.grid()
    plt.ylim(0,15)
longitude_vs_Wind_Speed()
